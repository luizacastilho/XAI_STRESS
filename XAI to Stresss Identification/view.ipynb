# %%
import matplotlib.pyplot as plt
from PIL import EpsImagePlugin
EpsImagePlugin.gs_windows_binary =  r"C:\Program Files\gs\gs10.03.0\bin\gswin64.exe"

plt.figure(figsize=(20, 10))
img = plt.imread(r"C:\Users\luiza\Documents\UFSC\TCC_Códigos\xai_stress\XAI to Stresss Identification\tree4.eps")
plt.imshow(img)
plt.axis("off")
plt.show()
